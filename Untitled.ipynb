# %%
RunningInCOLAB = 'google.colab' in str(get_ipython())
if RunningInCOLAB:
    # !pip install fooof
    # !git clone https://github.com/GregGlickert/Fooof-PSD-example.git
    # %cd Fooof-PSD-example

from fooof import FOOOF
from fooof.sim.gen import gen_aperiodic
import h5py
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import welch
# %matplotlib inline

# %% [markdown]
# # This code is to show how to use fooof using BMTK sim data. The data for this example was run for a simulation time of 15 seconds with a dt of 0.1
#
# ## We will first just look at the PSD of the raw data downsampled. We can see some bumps but need to filter out 1/f

# %%
use_fengs_data = False
ghghgjghghg
if use_fengs_data == False:
    f = h5py.File('ecp.h5','r')
    data = f['ecp']['data'][50000:][::10].reshape(-1,)
if use_fengs_data == True:
    data = np.loadtxt('LFP_elec_0')
freq, psd = plt.psd(data, NFFT=1024, Fs=1000)
plt.xlim(0,140)
plt.show()

# %% [markdown]
# ## We can use fooof to filter out the 1/f component and plot the residual

# %%
freqs,spectrum = welch(data,fs=1000,nfft=1024)
fm = FOOOF(aperiodic_mode='knee')
fm.fit(freqs, spectrum)
ap_fit = fm._ap_fit
residual_spec = spectrum[1:] - 10**ap_fit # making arrays match and making ap_fit linear scale

plt.plot(residual_spec)
plt.xlim([0,140])
# Out:
# FOOOF WARNING: Skipping frequency == 0, as this causes a problem with fitting.
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 9.77 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 freqs,spectrum = welch(data,fs=10000,nfft=1024)
#       2 fm = FOOOF(aperiodic_mode='knee')
# ----> 3 fm.fit(freqs, spectrum)
#       4 ap_fit = fm._ap_fit
#       5 residual_spec = spectrum[1:] - 10**ap_fit # making arrays match and making ap_fit linear scale
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/fooof/objs/fit.py:442, in FOOOF.fit(self, freqs, power_spectrum, freq_range)
#     439 self._spectrum_flat = self.power_spectrum - self._ap_fit
#     441 # Find peaks, and fit them with gaussians
# --> 442 self.gaussian_params_ = self._fit_peaks(np.copy(self._spectrum_flat))
#     444 # Calculate the peak fit
#     445 #   Note: if no peaks are found, this creates a flat (all zero) peak fit
#     446 self._peak_fit = gen_periodic(self.freqs, np.ndarray.flatten(self.gaussian_params_))
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/fooof/objs/fit.py:876, in FOOOF._fit_peaks(self, flat_iter)
#     874 # If there are peak guesses, fit the peaks, and sort results
#     875 if len(guess) > 0:
# --> 876     gaussian_params = self._fit_peak_guess(guess)
#     877     gaussian_params = gaussian_params[gaussian_params[:, 0].argsort()]
#     878 else:
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/fooof/objs/fit.py:926, in FOOOF._fit_peak_guess(self, guess)
#     924 # Fit the peaks
#     925 try:
# --> 926     gaussian_params, _ = curve_fit(gaussian_function, self.freqs, self._spectrum_flat,
#     927                                    p0=guess, maxfev=self._maxfev, bounds=gaus_param_bounds)
#     928 except RuntimeError:
#     929     raise FitError("Model fitting failed due to not finding "
#     930                    "parameters in the peak component fit.")
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:870, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     867 if 'max_nfev' not in kwargs:
#     868     kwargs['max_nfev'] = kwargs.pop('maxfev', None)
# --> 870 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     871                     **kwargs)
#     873 if not res.success:
#     874     raise RuntimeError("Optimal parameters not found: " + res.message)
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/scipy/optimize/_lsq/least_squares.py:938, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     934     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     935                           max_nfev, x_scale, diff_step)
#     937 elif method == 'trf':
# --> 938     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     939                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     940                  tr_options.copy(), verbose)
#     942 elif method == 'dogbox':
#     943     if tr_solver == 'lsmr' and 'regularize' in tr_options:
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/scipy/optimize/_lsq/trf.py:123, in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     119     return trf_no_bounds(
#     120         fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121         loss_function, tr_solver, tr_options, verbose)
#     122 else:
# --> 123     return trf_bounds(
#     124         fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125         loss_function, tr_solver, tr_options, verbose)
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/scipy/optimize/_lsq/trf.py:374, in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     370 f_true = f.copy()
#     372 cost = cost_new
# --> 374 J = jac(x, f)
#     375 njev += 1
#     377 if loss_function is not None:
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/scipy/optimize/_lsq/least_squares.py:896, in least_squares.<locals>.jac_wrapped(x, f)
#     895 def jac_wrapped(x, f):
# --> 896     J = approx_derivative(fun, x, rel_step=diff_step, method=jac,
#     897                           f0=f, bounds=bounds, args=args,
#     898                           kwargs=kwargs, sparsity=jac_sparsity)
#     899     if J.ndim != 2:  # J is guaranteed not sparse.
#     900         J = np.atleast_2d(J)
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:505, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     502     use_one_sided = False
#     504 if sparsity is None:
# --> 505     return _dense_difference(fun_wrapped, x0, f0, h,
#     506                              use_one_sided, method)
#     507 else:
#     508     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:576, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     574     x = x0 + h_vecs[i]
#     575     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 576     df = fun(x) - f0
#     577 elif method == '3-point' and use_one_sided[i]:
#     578     x1 = x0 + h_vecs[i]
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/scipy/optimize/_numdiff.py:456, in approx_derivative.<locals>.fun_wrapped(x)
#     455 def fun_wrapped(x):
# --> 456     f = np.atleast_1d(fun(x, *args, **kwargs))
#     457     if f.ndim > 1:
#     458         raise RuntimeError("`fun` return value has "
#     459                            "more than 1 dimension.")
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:501, in _wrap_func.<locals>.func_wrapped(params)
#     500 def func_wrapped(params):
# --> 501     return func(xdata, *params) - ydata
#
# File ~/opt/anaconda3/envs/bmtk/lib/python3.8/site-packages/fooof/core/funcs.py:39, in gaussian_function(xs, *params)
#      35 for ii in range(0, len(params), 3):
#      37     ctr, hgt, wid = params[ii:ii+3]
# ---> 39     ys = ys + hgt * np.exp(-(xs-ctr)**2 / (2*wid**2))
#      41 return ys
#
# KeyboardInterrupt:

# %% [markdown]
# # We can see the filter plot has a huge bump at around 45 Hz
